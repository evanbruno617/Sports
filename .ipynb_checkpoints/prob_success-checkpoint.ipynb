# %%
import numpy as np
import pandas as pd
import datetime

# %%
stealing_df = pd.read_csv('combined.csv')

stealing_df.drop(columns=['Unnamed: 0'], inplace=True)

stealing_df.head()
# Out:
#   Start_Base End_Base               Event Respon_Pitcher  runner_id  \
# 0         1B      NaN  Caught Stealing 2B            NaN     545341
# 1         1B       2B      Stolen Base 2B            NaN     643565
# 2         2B       3B      Stolen Base 3B            NaN     643565
# 3         1B       2B      Stolen Base 2B            NaN     666185
# 4         2B       3B      Stolen Base 3B            NaN     502054
#
#       runner_name  pitcher_id     pitcher_name  batter_id    batter_name  \
# 0  Randal Grichuk      643338       Chad Green     543760  Marcus Semien
# 1   Mike Tauchman      605447    Jordan Romano     457803      Jay Bruce
# 2   Mike Tauchman      605447    Jordan Romano     640449  Clint Frazier
# 3   Dylan Carlson      489334    Craig Stammen     425877  Yadier Molina
# 4      Tommy Pham      650893  Génesis Cabrera     543592    Austin Nola
#
#   pitch_hand         credit  credit_id  homeScore  awayScore  inning  \
# 0          R   Gary Sánchez     596142          2          2       7
# 1          R   Danny Jansen     643376          2          2       9
# 2          R   Danny Jansen     643376          2          2       9
# 3          R    Austin Nola     543592          3          6       4
# 4          L  Yadier Molina     425877          4          6       6
#
#    isTopInning        Date  Action Base
# 0         True  2021-04-01  Caught   2B
# 1        False  2021-04-01  Stolen   2B
# 2        False  2021-04-01  Stolen   3B
# 3         True  2020-09-30  Stolen   2B
# 4        False  2020-09-30  Stolen   3B

# %%
stealing_df['Date'] = pd.to_datetime(stealing_df['Date'])

# %%
runner_df = pd.read_csv('Runner_final/A.J. Pierzynski.csv')
runner_df['Date'] = pd.to_datetime(runner_df['Date'])
runner_df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Start_Base  End_Base               Event  \
# 0             0         111         1B       NaN  Caught Stealing 2B
# 1             1        1810         1B       NaN  Caught Stealing 2B
#
#    runner_id      runner_name  pitcher_id   pitcher_name  batter_id  ...  \
# 0     150229  A.J. Pierzynski      452657     Jon Lester     346874  ...
# 1     150229  A.J. Pierzynski      112526  Bartolo Colon     592743  ...
#
#   homeScore awayScore inning  isTopInning       Date  Action  Base  Year  \
# 0         0         0      2        False 2015-07-18  Caught    2B  2015
# 1         4         3      6         True 2015-04-23  Caught    2B  2015
#
#   Current_Year Sprint
# 0         2016   24.5
# 1         2016   24.5
#
# [2 rows x 24 columns]

# %%
pd.read_csv('Runner_final/A.J. Pierzynski.csv')
# Out:
#    Unnamed: 0.1  Unnamed: 0 Start_Base  End_Base               Event  \
# 0             0         111         1B       NaN  Caught Stealing 2B
# 1             1        1810         1B       NaN  Caught Stealing 2B
#
#    runner_id      runner_name  pitcher_id   pitcher_name  batter_id  ...  \
# 0     150229  A.J. Pierzynski      452657     Jon Lester     346874  ...
# 1     150229  A.J. Pierzynski      112526  Bartolo Colon     592743  ...
#
#   homeScore awayScore inning  isTopInning        Date  Action  Base  Year  \
# 0         0         0      2        False  2015-07-18  Caught    2B  2015
# 1         4         3      6         True  2015-04-23  Caught    2B  2015
#
#   Current_Year Sprint
# 0         2016   24.5
# 1         2016   24.5
#
# [2 rows x 24 columns]

# %%
runner_df
# Out:
#    Unnamed: 0.1  Unnamed: 0 Start_Base  End_Base               Event  \
# 0             0         111         1B       NaN  Caught Stealing 2B
# 1             1        1810         1B       NaN  Caught Stealing 2B
#
#    runner_id      runner_name  pitcher_id   pitcher_name  batter_id  ...  \
# 0     150229  A.J. Pierzynski      452657     Jon Lester     346874  ...
# 1     150229  A.J. Pierzynski      112526  Bartolo Colon     592743  ...
#
#   homeScore awayScore inning  isTopInning       Date  Action  Base  Year  \
# 0         0         0      2        False 2015-07-18  Caught    2B  2015
# 1         4         3      6         True 2015-04-23  Caught    2B  2015
#
#   Current_Year Sprint
# 0         2016   24.5
# 1         2016   24.5
#
# [2 rows x 24 columns]

# %%
runner_df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Start_Base', 'End_Base', 'Event',
#        'runner_id', 'runner_name', 'pitcher_id', 'pitcher_name', 'batter_id',
#        'batter_name', 'pitch_hand', 'credit', 'credit_id', 'homeScore',
#        'awayScore', 'inning', 'isTopInning', 'Date', 'Action', 'Base', 'Year',
#        'Current_Year', 'Sprint'],
#       dtype='object')

# %%
runner_df['Start_Base_num']  = runner_df['Start_Base'].apply(lambda x: 1 if x == '1B' else (2 if x == '2B' else 3))

# %%
runner_df.loc[(runner_df['Date'] <= pd.to_datetime('2015-07-10'))].head(30)
# Out:
#    Unnamed: 0.1  Unnamed: 0 Start_Base  End_Base               Event  \
# 1             1        1810         1B       NaN  Caught Stealing 2B
#
#    runner_id      runner_name  pitcher_id   pitcher_name  batter_id  ...  \
# 1     150229  A.J. Pierzynski      112526  Bartolo Colon     592743  ...
#
#   awayScore inning isTopInning       Date  Action  Base  Year  Current_Year  \
# 1         3      6        True 2015-04-23  Caught    2B  2015          2016
#
#   Sprint Start_Base_num
# 1   24.5              1
#
# [1 rows x 25 columns]

# %%
runner_df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Start_Base', 'End_Base', 'Event',
#        'runner_id', 'runner_name', 'pitcher_id', 'pitcher_name', 'batter_id',
#        'batter_name', 'pitch_hand', 'credit', 'credit_id', 'homeScore',
#        'awayScore', 'inning', 'isTopInning', 'Date', 'Action', 'Base', 'Year',
#        'Current_Year', 'Sprint', 'Start_Base_num'],
#       dtype='object')

# %%
runner_df['credit']
# Out:
# 0        David Ross
# 1    Anthony Recker
# Name: credit, dtype: object

# %%
date
# Out:
# Timestamp('2021-04-01 00:00:00')

# %%
catcher_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 catcher_name
#
# NameError: name 'catcher_name' is not defined

# %%
for row, i in stealing_df.iterrows():
    catcher_id = i['credit_id']
    
    runner_id = i['pitcher_id']
    
    catcher_name = i['credit']
    
    runner_name = i['runner_name']
    
    date = i['Date']
    
    try:
    
        runner_df = pd.read_csv(f'Runner_final/{runner_name}.csv')

        catcher_df = pd.read_csv(f'catchers/{catcher_name}.csv')
        
        
    except:
        print(catcher_name)
        continue
    
    runner_df.loc[runner_df['Date'] <= date]
# Out:
# Danny Jansen
# Robinson Chirinos
# Juan Graterol
# James McCann
# Jacob Stallings
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
#      20     print(catcher_name)
#      21     continue
# ---> 23 runner_df.loc[runner_df['Date'] <= date]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:52, in OpsMixin.__le__(self, other)
#      50 @unpack_zerodim_and_defer("__le__")
#      51 def __le__(self, other):
# ---> 52     return self._cmp_method(other, operator.le)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:5622, in Series._cmp_method(self, other, op)
#    5619 lvalues = self._values
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 5622 with np.errstate(all="ignore"):
#    5623     res_values = ops.comparison_op(lvalues, rvalues, op)
#    5625 return self._construct_result(res_values, name=res_name)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_ufunc_config.py:430, in errstate.__enter__(self)
#     429 def __enter__(self):
# --> 430     self.oldstate = seterr(**self.kwargs)
#     431     if self.call is not _Unspecified:
#     432         self.oldcall = seterrcall(self.call)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_ufunc_config.py:110, in seterr(all, divide, over, under, invalid)
#      34 """
#      35 Set how floating-point errors are handled.
#      36
#    (...)
#     106
#     107 """
#     109 pyvals = umath.geterrobj()
# --> 110 old = geterr()
#     112 if divide is None:
#     113     divide = all or old['divide']
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_ufunc_config.py:171, in geterr()
#     169 res = {}
#     170 val = (maskvalue >> SHIFT_DIVIDEBYZERO) & mask
# --> 171 res['divide'] = _errdict_rev[val]
#     172 val = (maskvalue >> SHIFT_OVERFLOW) & mask
#     173 res['over'] = _errdict_rev[val]
#
# KeyboardInterrupt:

# %%
print(catcher_name)
# Out:
# Jacob Stallings

# %%
catcher_df[['credit']]
# Out:
#          credit
# 0    Tom Murphy
# 1    Tom Murphy
# 2    Tom Murphy
# 3    Tom Murphy
# 4    Tom Murphy
# ..          ...
# 315  Tom Murphy
# 316  Tom Murphy
# 317  Tom Murphy
# 318  Tom Murphy
# 319  Tom Murphy
#
# [320 rows x 1 columns]

# %%
runner_df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Start_Base', 'End_Base', 'Event',
#        'runner_id', 'runner_name', 'pitcher_id', 'pitcher_name', 'batter_id',
#        'batter_name', 'pitch_hand', 'credit', 'credit_id', 'homeScore',
#        'awayScore', 'inning', 'isTopInning', 'Date', 'Action', 'Base', 'Year',
#        'Current_Year', 'Sprint'],
#       dtype='object')
