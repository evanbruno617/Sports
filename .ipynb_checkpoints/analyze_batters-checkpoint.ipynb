# %%
import pandas as pd
import numpy as np
import os

# %%
# Replace 'your_directory_path' with the path to your folder
folder_path = 'atbat'

# List all CSV files in the folder
csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

# %%
csv_files
# Out:
# ['2020.csv',
#  '2021.csv',
#  '2023.csv',
#  '2022.csv',
#  '2019.csv',
#  '2018.csv',
#  '2024.csv',
#  '2015.csv',
#  '2014.csv',
#  '2016.csv',
#  '2017.csv']

# %%
final = pd.DataFrame()

for file in csv_files:
    
    data = pd.read_csv(f'atbat/{file}')
    
    final = pd.concat([data, final])

# %%
final = final.sort_values(by='Date')
final.to_csv('atbats.csv')

# %%
final.drop(columns=['Unnamed: 0'], inplace=True)

# %%
final.head()
# Out:
#        Outcome  Rbi   Bases  Batter_id    Batter_name Pitcher  Isout  Outs  \
# 644  strikeout    0   Empty     449107    Mike Aviles  vs_LHP   True     2
# 435   home_run    3   Empty     474832   Brandon Belt  vs_LHP  False     2
# 436  field_out    0   Empty     435078  Joaquin Arias  vs_LHP   True     3
# 437     single    0   Empty     467827  Gerardo Parra  vs_RHP  False     0
# 438  field_out    0  Men_On     431094     Aaron Hill  vs_RHP   True     1
#
#      homeScore  awayScore  inning  isTopInning   bases        Date
# 644          4          3       8         True   Empty  2014-04-01
# 435          0          4       1         True   Empty  2014-04-01
# 436          0          4       1         True   Empty  2014-04-01
# 437          0          4       1        False   Empty  2014-04-01
# 438          0          4       1        False  Men_On  2014-04-01

# %%
final['Current_outs'] = final.apply(lambda x: x['Outs'] - 1 if x['Isout'] == True else x['Outs'], axis=1)

# %%
final['Scoring_pos'] = final['Bases'].apply(lambda x: 1 if x == 'RISP' else 0)

# %%
final
# Out:
#              Outcome  Rbi   Bases  Batter_id      Batter_name Pitcher  Isout  \
# 644        strikeout    0   Empty     449107      Mike Aviles  vs_LHP   True
# 435         home_run    3   Empty     474832     Brandon Belt  vs_LHP  False
# 436        field_out    0   Empty     435078    Joaquin Arias  vs_LHP   True
# 437           single    0   Empty     467827    Gerardo Parra  vs_RHP  False
# 438        field_out    0  Men_On     431094       Aaron Hill  vs_RHP   True
# ...              ...  ...     ...        ...              ...     ...    ...
# 181292  hit_by_pitch    0   Empty     642201        Eli White  vs_RHP  False
# 181291     field_out    0   Empty     621438    Tyrone Taylor  vs_LHP   True
# 181290          walk    0   Empty     502110    J.D. Martinez  vs_LHP  False
# 181288      home_run    2   Empty     607043    Brandon Nimmo  vs_RHP  False
# 181308     field_out    0    RISP     518595  Travis d'Arnaud  vs_RHP   True
#
#         Outs  homeScore  awayScore  inning  isTopInning   bases        Date  \
# 644        2          4          3       8         True   Empty  2014-04-01
# 435        2          0          4       1         True   Empty  2014-04-01
# 436        3          0          4       1         True   Empty  2014-04-01
# 437        0          0          4       1        False   Empty  2014-04-01
# 438        1          0          4       1        False  Men_On  2014-04-01
# ...      ...        ...        ...     ...          ...     ...         ...
# 181292     0          3          6       8        False   Empty  2024-09-30
# 181291     3          3          6       8         True   Empty  2024-09-30
# 181290     2          3          6       8         True   Empty  2024-09-30
# 181288     1          3          6       8         True   Empty  2024-09-30
# 181308     3          7          8       9        False    RISP  2024-09-30
#
#         Current_outs  Scoring_pos
# 644                1            0
# 435                2            0
# 436                2            0
# 437                0            0
# 438                0            0
# ...              ...          ...
# 181292             0            0
# 181291             2            0
# 181290             2            0
# 181288             1            0
# 181308             2            1
#
# [1932242 rows x 16 columns]

# %%
rbis_df = final.loc[(final['Rbi'] >= 1) & (final['Scoring_pos'] == 1)]
rbis_df
# Out:
#                 Outcome  Rbi Bases  Batter_id     Batter_name Pitcher  Isout  \
# 440              single    1  RISP     445988    Martín Prado  vs_RHP  False
# 420              single    1  RISP     133380  Aramis Ramirez  vs_RHP  False
# 480             sac_fly    1  RISP     467827   Gerardo Parra  vs_RHP   True
# 357              single    1  RISP     134181   Adrian Beltré  vs_RHP  False
# 340              double    1  RISP     134181   Adrian Beltré  vs_LHP  False
# ...                 ...  ...   ...        ...             ...     ...    ...
# 180301  fielders_choice    1  RISP     657136     Connor Wong  vs_LHP  False
# 180612        field_out    1  RISP     694388  Joey Loperfido  vs_RHP   True
# 181321           single    1  RISP     570482     Gio Urshela  vs_LHP  False
# 181363           single    2  RISP     542303   Marcell Ozuna  vs_RHP  False
# 181296           single    1  RISP     672284  Jarred Kelenic  vs_RHP  False
#
#         Outs  homeScore  awayScore  inning  isTopInning bases        Date  \
# 440        1          2          4       1        False  RISP  2014-04-01
# 420        2          2          4       8        False  RISP  2014-04-01
# 480        2          5          4       6        False  RISP  2014-04-01
# 357        1          3          2       9        False  RISP  2014-04-01
# 340        2          2          2       7        False  RISP  2014-04-01
# ...      ...        ...        ...     ...          ...   ...         ...
# 180301     1          3          1       5        False  RISP  2024-09-29
# 180612     2          1          3       7        False  RISP  2024-09-29
# 181321     1          1          0       2        False  RISP  2024-09-30
# 181363     2          3          0       7        False  RISP  2024-09-30
# 181296     2          4          6       8        False  RISP  2024-09-30
#
#         Current_outs  Scoring_pos
# 440                1            1
# 420                2            1
# 480                1            1
# 357                1            1
# 340                2            1
# ...              ...          ...
# 180301             1            1
# 180612             1            1
# 181321             1            1
# 181363             2            1
# 181296             2            1
#
# [45325 rows x 16 columns]

# %%
rbis_df['Outcome'].unique()
# Out:
# array(['double', 'single', 'sac_fly', 'field_out', 'force_out', 'triple',
#        'fielders_choice', 'field_error', 'sac_bunt',
#        'sac_fly_double_play', 'fielders_choice_out', 'walk'], dtype=object)

# %%
final.loc[(final['Scoring_pos'] == 1)]['Outcome'].unique()
# Out:
# array(['double', 'walk', 'strikeout', 'single', 'force_out', 'field_out',
#        'sac_fly', 'intent_walk', 'sac_bunt', 'triple', 'field_error',
#        'hit_by_pitch', 'catcher_interf', 'grounded_into_double_play',
#        'fielders_choice', 'fielders_choice_out', 'double_play',
#        'sac_fly_double_play', 'balk', 'strikeout_double_play',
#        'passed_ball', 'wild_pitch', 'pitching_substitution',
#        'game_advisory'], dtype=object)

# %%
final['Outcome'].unique()
# Out:
# array(['strikeout', 'home_run', 'field_out', 'single', 'double', 'walk',
#        'grounded_into_double_play', 'force_out', 'sac_fly', 'intent_walk',
#        'sac_bunt', 'double_play', 'triple', 'hit_by_pitch', 'field_error',
#        'pickoff_1b', 'sac_fly_double_play', 'fielders_choice',
#        'catcher_interf', 'fielders_choice_out', 'caught_stealing_2b',
#        'strikeout_double_play', 'pickoff_caught_stealing_2b',
#        'caught_stealing_3b', 'pickoff_2b', 'other_out', 'wild_pitch',
#        'pickoff_caught_stealing_3b', 'triple_play', 'runner_double_play',
#        'pickoff_3b', 'caught_stealing_home',
#        'pickoff_caught_stealing_home', 'balk', 'pickoff_error_1b',
#        'sac_bunt_double_play', 'pitching_substitution', 'passed_ball',
#        'ejection', 'stolen_base_2b', 'stolen_base_3b', 'pickoff_error_2b',
#        'game_advisory', 'stolen_base_home', 'pickoff_error_3b'],
#       dtype=object)

# %%
third = ['force_out', 'sac_fly', 'field_out', 'field_error', 'fielders_choice', 'sac_bunt', 'sac_fly_double_play', 'fielders_choice_out']

second = ['double', 'single', 'triple']

final['player_position'] = final['Outcome'].apply(lambda x: 3 if x in third else (2 if x in second else 0))

# %%
final
# Out:
#              Outcome  Rbi   Bases  Batter_id      Batter_name Pitcher  Isout  \
# 644        strikeout    0   Empty     449107      Mike Aviles  vs_LHP   True
# 435         home_run    3   Empty     474832     Brandon Belt  vs_LHP  False
# 436        field_out    0   Empty     435078    Joaquin Arias  vs_LHP   True
# 437           single    0  Men_On     467827    Gerardo Parra  vs_RHP  False
# 438        field_out    0  Men_On     431094       Aaron Hill  vs_RHP   True
# ...              ...  ...     ...        ...              ...     ...    ...
# 181292  hit_by_pitch    0  Men_On     642201        Eli White  vs_RHP  False
# 181291     field_out    0   Empty     621438    Tyrone Taylor  vs_LHP   True
# 181290          walk    0  Men_On     502110    J.D. Martinez  vs_LHP  False
# 181288      home_run    2   Empty     607043    Brandon Nimmo  vs_RHP  False
# 181308     field_out    0   Empty     518595  Travis d'Arnaud  vs_RHP   True
#
#         Outs  homeScore  awayScore  inning  isTopInning        Date  \
# 644        2          4          3       8         True  2014-04-01
# 435        2          0          4       1         True  2014-04-01
# 436        3          0          4       1         True  2014-04-01
# 437        0          0          4       1        False  2014-04-01
# 438        1          0          4       1        False  2014-04-01
# ...      ...        ...        ...     ...          ...         ...
# 181292     0          3          6       8        False  2024-09-30
# 181291     3          3          6       8         True  2024-09-30
# 181290     2          3          6       8         True  2024-09-30
# 181288     1          3          6       8         True  2024-09-30
# 181308     3          7          8       9        False  2024-09-30
#
#         Current_outs  Scoring_pos  player_position
# 644                1            0                0
# 435                2            0                0
# 436                2            0                3
# 437                0            0                2
# 438                0            0                3
# ...              ...          ...              ...
# 181292             0            0                0
# 181291             2            0                3
# 181290             2            0                0
# 181288             1            0                0
# 181308             2            0                3
#
# [1932242 rows x 16 columns]

# %%
test = final.loc[final['Batter_name'] == 'Buster Posey']

# %%
test
# Out:
#           Outcome  Rbi   Bases  Batter_id   Batter_name Pitcher  Isout  Outs  \
# 433        single    1   Empty     457763  Buster Posey  vs_LHP  False     1
# 474          walk    0   Empty     457763  Buster Posey  vs_LHP  False     2
# 453     field_out    0   Empty     457763  Buster Posey  vs_LHP   True     3
# 493     strikeout    0   Empty     457763  Buster Posey  vs_RHP   True     2
# 1744       single    0   Empty     457763  Buster Posey  vs_RHP  False     1
# ...           ...  ...     ...        ...           ...     ...    ...   ...
# 183004     single    0   Empty     457763  Buster Posey  vs_RHP  False     1
# 183983  field_out    0   Empty     457763  Buster Posey  vs_RHP   True     1
# 183945    sac_fly    1    RISP     457763  Buster Posey  vs_LHP   True     1
# 183962     double    1  Men_On     457763  Buster Posey  vs_LHP  False     1
# 183926  field_out    0    RISP     457763  Buster Posey  vs_LHP   True     1
#
#         homeScore  awayScore  inning  isTopInning   bases        Date  \
# 433             0          1       1         True   Empty  2014-04-01
# 474             3          4       6         True   Empty  2014-04-01
# 453             2          4       3         True   Empty  2014-04-01
# 493             5          4       8         True   Empty  2014-04-01
# 1744            0          1       6         True   Empty  2014-04-02
# ...           ...        ...     ...          ...     ...         ...
# 183004          0          0       5        False   Empty  2021-09-29
# 183983          4          4       8        False   Empty  2021-09-30
# 183945          2          3       3        False    RISP  2021-09-30
# 183962          4          4       5        False  Men_On  2021-09-30
# 183926          1          3       1        False    RISP  2021-09-30
#
#         Current_outs  Scoring_pos
# 433                1            0
# 474                2            0
# 453                2            0
# 493                1            0
# 1744               1            0
# ...              ...          ...
# 183004             1            0
# 183983             0            0
# 183945             0            1
# 183962             1            0
# 183926             0            1
#
# [3747 rows x 16 columns]

# %%
rbis_df = test.loc[(test['Rbi'] >= 1) & (test['Scoring_pos'] == 1)]
rbis_df
# Out:
#         Outcome  Rbi Bases  Batter_id   Batter_name Pitcher  Isout  Outs  \
# 433      single    1  RISP     457763  Buster Posey  vs_LHP  False     1
# 7040     single    1  RISP     457763  Buster Posey  vs_RHP  False     1
# 16340    single    1  RISP     457763  Buster Posey  vs_LHP  False     1
# 31000    single    1  RISP     457763  Buster Posey  vs_RHP  False     2
# 35836    single    1  RISP     457763  Buster Posey  vs_LHP  False     0
# ...         ...  ...   ...        ...           ...     ...    ...   ...
# 160468   double    1  RISP     457763  Buster Posey  vs_RHP  False     0
# 174932  sac_fly    1  RISP     457763  Buster Posey  vs_RHP   True     2
# 175884   double    1  RISP     457763  Buster Posey  vs_RHP  False     0
# 177772   single    1  RISP     457763  Buster Posey  vs_RHP  False     1
# 183962   double    1  RISP     457763  Buster Posey  vs_LHP  False     1
#
#         homeScore  awayScore  inning  isTopInning        Date  Current_outs  \
# 433             0          1       1         True  2014-04-01             1
# 7040            3          1       3        False  2014-04-08             1
# 16340           1          0       3        False  2014-04-16             1
# 31000           3          0       7        False  2014-04-30             2
# 35836           8          3       6         True  2014-05-05             0
# ...           ...        ...     ...          ...         ...           ...
# 160468          0          2       1         True  2021-09-07             0
# 174932          4          3       5         True  2021-09-21             1
# 175884          1          6       7         True  2021-09-22             0
# 177772          2          7       7         True  2021-09-24             1
# 183962          4          4       5        False  2021-09-30             1
#
#         Scoring_pos
# 433               1
# 7040              1
# 16340             1
# 31000             1
# 35836             1
# ...             ...
# 160468            1
# 174932            1
# 175884            1
# 177772            1
# 183962            1
#
# [172 rows x 15 columns]

# %%
scoring_pos = test[(test['Scoring_pos'] == 1)]
scoring_pos
# Out:
#             Outcome  Rbi Bases  Batter_id   Batter_name Pitcher  Isout  Outs  \
# 7040         single    1  RISP     457763  Buster Posey  vs_RHP  False     1
# 9076           walk    0  RISP     457763  Buster Posey  vs_RHP  False     2
# 9759         single    1  RISP     457763  Buster Posey  vs_RHP  False     2
# 11395          walk    0  RISP     457763  Buster Posey  vs_RHP  False     0
# 14865          walk    0  RISP     457763  Buster Posey  vs_RHP  False     1
# ...             ...  ...   ...        ...           ...     ...    ...   ...
# 167571       single    0  RISP     457763  Buster Posey  vs_RHP  False     1
# 167539    field_out    0  RISP     457763  Buster Posey  vs_LHP   True     3
# 170691  intent_walk    0  RISP     457763  Buster Posey  vs_LHP  False     1
# 183945      sac_fly    1  RISP     457763  Buster Posey  vs_LHP   True     1
# 183926    field_out    0  RISP     457763  Buster Posey  vs_LHP   True     1
#
#         homeScore  awayScore  inning  isTopInning bases        Date  \
# 7040            3          1       3        False  RISP  2014-04-08
# 9076            0          3       1        False  RISP  2014-04-09
# 9759            2          4       3        False  RISP  2014-04-10
# 11395           0          1       4        False  RISP  2014-04-12
# 14865           0          1       4        False  RISP  2014-04-15
# ...           ...        ...     ...          ...   ...         ...
# 167571          6          1       8        False  RISP  2021-09-14
# 167539          3          1       4        False  RISP  2021-09-14
# 170691          5          5      10        False  RISP  2021-09-17
# 183945          2          3       3        False  RISP  2021-09-30
# 183926          1          3       1        False  RISP  2021-09-30
#
#         Current_outs  Scoring_pos
# 7040               1            1
# 9076               2            1
# 9759               2            1
# 11395              0            1
# 14865              1            1
# ...              ...          ...
# 167571             1            1
# 167539             2            1
# 170691             1            1
# 183945             0            1
# 183926             0            1
#
# [428 rows x 16 columns]

# %% [markdown]
# do one jsut for risp and do for all general atbats  /do langrage and machine learning

# %%
date = '2019-07-10'

# %%
current_events = scoring_pos.loc[scoring_pos['Date'] < date].tail(30)

# %%
current_events
# Out:
#           Outcome  Rbi Bases  Batter_id   Batter_name Pitcher  Isout  Outs  \
# 31430      single    1  RISP     457763  Buster Posey  vs_RHP  False     2
# 31370   field_out    0  RISP     457763  Buster Posey  vs_LHP   True     2
# 32598   field_out    0  RISP     457763  Buster Posey  vs_RHP   True     2
# 35394      double    0  RISP     457763  Buster Posey  vs_RHP  False     1
# 38677      single    0  RISP     457763  Buster Posey  vs_RHP  False     0
# 47393      double    0  RISP     457763  Buster Posey  vs_RHP  False     2
# 47409   field_out    0  RISP     457763  Buster Posey  vs_RHP   True     2
# 48610   strikeout    0  RISP     457763  Buster Posey  vs_RHP   True     1
# 51514      single    0  RISP     457763  Buster Posey  vs_RHP  False     1
# 55501   field_out    0  RISP     457763  Buster Posey  vs_RHP   True     1
# 57203      double    1  RISP     457763  Buster Posey  vs_RHP  False     1
# 60541      double    0  RISP     457763  Buster Posey  vs_RHP  False     0
# 60479   field_out    0  RISP     457763  Buster Posey  vs_RHP   True     2
# 62985        walk    0  RISP     457763  Buster Posey  vs_RHP  False     1
# 77332      single    0  RISP     457763  Buster Posey  vs_RHP  False     0
# 79489        walk    0  RISP     457763  Buster Posey  vs_RHP  False     1
# 83815      double    0  RISP     457763  Buster Posey  vs_LHP  False     2
# 83894   field_out    0  RISP     457763  Buster Posey  vs_RHP   True     2
# 90943   field_out    0  RISP     457763  Buster Posey  vs_RHP   True     1
# 90921   field_out    0  RISP     457763  Buster Posey  vs_RHP   True     2
# 92006      double    1  RISP     457763  Buster Posey  vs_RHP  False     2
# 92044      single    0  RISP     457763  Buster Posey  vs_LHP  False     0
# 92026      single    1  RISP     457763  Buster Posey  vs_RHP  False     2
# 94751      double    2  RISP     457763  Buster Posey  vs_LHP  False     0
# 94738   field_out    0  RISP     457763  Buster Posey  vs_LHP   True     1
# 95852        walk    0  RISP     457763  Buster Posey  vs_RHP  False     1
# 95824   field_out    0  RISP     457763  Buster Posey  vs_LHP   True     2
# 99079      single    0  RISP     457763  Buster Posey  vs_RHP  False     0
# 100004     single    0  RISP     457763  Buster Posey  vs_RHP  False     1
# 100053  strikeout    0  RISP     457763  Buster Posey  vs_LHP   True     2
#
#         homeScore  awayScore  inning  isTopInning        Date  Current_outs  \
# 31430           2          1       9        False  2019-05-01             2
# 31370           1          0       1        False  2019-05-01             1
# 32598           0          0       1         True  2019-05-03             1
# 35394           4          4       9         True  2019-05-05             1
# 38677           0          0       1         True  2019-05-08             0
# 47393           0          0       1         True  2019-05-17             2
# 47409           0          0       3         True  2019-05-17             1
# 48610           0          0       1         True  2019-05-18             0
# 51514           0          1       1        False  2019-05-21             1
# 55501           1          5       3        False  2019-05-25             0
# 57203           1          2       1        False  2019-05-26             1
# 60541           4          1       9         True  2019-05-29             0
# 60479           0          0       1         True  2019-05-29             1
# 62985           0          0       1         True  2019-06-01             1
# 77332           5          3       8        False  2019-06-14             0
# 79489           0          1       1        False  2019-06-16             1
# 83815           0          0       1         True  2019-06-20             2
# 83894           9          8       9         True  2019-06-20             1
# 90943           1          5       9        False  2019-06-27             0
# 90921           1          2       6        False  2019-06-27             1
# 92006           2          0       3        False  2019-06-28             2
# 92044           4          2       7        False  2019-06-28             0
# 92026           3          1       5        False  2019-06-28             2
# 94751           0          6       5         True  2019-07-01             0
# 94738           0          0       4         True  2019-07-01             0
# 95852           1          7       8         True  2019-07-02             1
# 95824           1          3       5         True  2019-07-02             1
# 99079           0          3       1        False  2019-07-05             0
# 100004          0          1       1        False  2019-07-06             1
# 100053          5          1       7        False  2019-07-06             1
#
#         Scoring_pos  player_position
# 31430             1                2
# 31370             1                3
# 32598             1                3
# 35394             1                2
# 38677             1                2
# 47393             1                2
# 47409             1                3
# 48610             1                0
# 51514             1                2
# 55501             1                3
# 57203             1                2
# 60541             1                2
# 60479             1                3
# 62985             1                0
# 77332             1                2
# 79489             1                0
# 83815             1                2
# 83894             1                3
# 90943             1                3
# 90921             1                3
# 92006             1                2
# 92044             1                2
# 92026             1                2
# 94751             1                2
# 94738             1                3
# 95852             1                0
# 95824             1                3
# 99079             1                2
# 100004            1                2
# 100053            1                0

# %%
final['Outcome'].unique()
# Out:
# array(['strikeout', 'home_run', 'field_out', 'single', 'double', 'walk',
#        'grounded_into_double_play', 'force_out', 'sac_fly', 'intent_walk',
#        'sac_bunt', 'double_play', 'triple', 'hit_by_pitch', 'field_error',
#        'pickoff_1b', 'sac_fly_double_play', 'fielders_choice',
#        'catcher_interf', 'fielders_choice_out', 'caught_stealing_2b',
#        'strikeout_double_play', 'pickoff_caught_stealing_2b',
#        'caught_stealing_3b', 'pickoff_2b', 'other_out', 'wild_pitch',
#        'pickoff_caught_stealing_3b', 'triple_play', 'runner_double_play',
#        'pickoff_3b', 'caught_stealing_home',
#        'pickoff_caught_stealing_home', 'balk', 'pickoff_error_1b',
#        'sac_bunt_double_play', 'pitching_substitution', 'passed_ball',
#        'ejection', 'stolen_base_2b', 'stolen_base_3b', 'pickoff_error_2b',
#        'game_advisory', 'stolen_base_home', 'pickoff_error_3b'],
#       dtype=object)

# %%
final['Bases'].unique()
# Out:
# array(['Empty', 'Men_On', 'RISP', 'Loaded'], dtype=object)
